# %% [markdown]
# # Sentiment Analysis - Class Exercise (TAU Text Mining for Business, 24'/25')

# %% [markdown]
# ## Dataset

# %%
sentences = [
    "Awful experience. I would never buy this product again!",
    "Overall, I had a good time, even though I felt bad",
    "Not bad!!!",
    "Great service :-((((",
    "I'm so sorry for your loss",
]

# %% [markdown]
# # A - Lexicon-based Sentiment Analysis

# %% [markdown]
# As was tradition in days of yore...

# %% [markdown]
# ## 1. Sentiment Analysis with VADER

# %% [markdown]
# ### Q1: Setup VADER
#
# Import `pandas`, and the VADER sentiment analyzer from `nltk`, download the `'vader_lexicon'` resource in `nltk` and initialize a VADER object.
#
# **Hint:**
#
# 1. https://www.nltk.org/api/nltk.sentiment.vader.html
# 2. https://www.nltk.org/data.html (NOTE: Always run the `download` method with an argument supplied, not with empty `()`!)

# %% [markdown]
# ### Q2: Get the VADER polarity for each sentence
#
# Buid a dataframe with two columns: `"sentence"` containing the text of a sentence, and `"VADER"` containing the compound polarity score VADER outputs for that sentence. Then, `display` it.
#
# **Hint: Take a look at the object the `polarity_scores` method returns for a single sentence.**

# %% [markdown]
# ## 2. Sentiment Analysis with Text Blob

# %% [markdown]
# ### Q3: Setup Textblob
#
# Setup the `textblob` Python package (`pip` install it if required).
#
# **Hint:**
#
# https://textblob.readthedocs.io/en/dev/index.html

# %% [markdown]
# ### Q4: Textblob polarity scores
#
# Buid a dataframe with two columns: `"sentence"` containing the text of a sentence, and `"textblob"` containing the sentiment polarity score `TextBlob` outputs for that sentence. Then, `display` it.
#
# **Hint:**
#
# 1. https://textblob.readthedocs.io/en/dev/quickstart.html#sentiment-analysis
# 2. Search google for `pd.options.display.float_format` if dataframe display is weird.

# %% [markdown]
# # B - Pretrained Sentiment Analyzer

# %% [markdown]
# ## 3. Sentiment Analysis with BERT

# %% [markdown]
# Import `pipeline` from the `transformers` package (install it if it's not already installed).

# %% [markdown]
# ### Q5: Build a basic, BERT-based sentiment analysis pipeline
#
# Run the below code.

# %%
sentiment_cls = pipeline(
    'sentiment-analysis',
    model='Seethal/sentiment_analysis_generic_dataset',
    tokenizer='Seethal/sentiment_analysis_generic_dataset',
    device=-1)

# %% [markdown]
# **WAIT for everything to finish downloading!**

# %% [markdown]
# ### Q6: Use the pipeline to infer sentiment
#
# Build a dataframe like we did for the previous models.
#
# **Hints:**
# 1. `sentiment_cls` is a callable. Feed it a sentence and examine the output format.
# 2. You can think of `score` as the confidence of the model in its prediction. Include it in your dataframe.

# %% [markdown]
# ### Q7: Try another model!
#
# Repeat you experiment with another sentiment analysis-capable model from HuggingFace.
# Try and find a model that will perform better on example 3 (the fourth example).
#
# **Hints:**
# 1. Search huggingface.co for more sentiment models: https://huggingface.co/models?sort=downloads&search=sentiment
# 2. Look for `distilbert`-based models for smaller models.
